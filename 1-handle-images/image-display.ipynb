# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('../images/car-image.jpeg', 0)
plt.imshow(img, cmap = 'gray')
# plt.xticks([]), plt.yticks([])  # hide X and Y axis
plt.show()
